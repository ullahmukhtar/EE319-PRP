# %% [markdown]
# # EE319 - Probability & Random Processes
# ## Dr. Ing. Mukhtar Ullah, FAST NUCES, Fall 2020
# ## **Lecture 02** (2020-01-24)
# ## How to Mathematize Uncertainty
# Recall your previous exposure to theories
# ## Examples of Deterministic Theories
# - Circuit Theory
#  - Circuit elements (lumped models with idealized V-I characteristics)
#  - Kirchhoff laws (interactions between circuit elements)<br>
# __Name the relevant courses you took__
# - Network Theory
#  - Network elements (1-port and 2-port)
#  - Network laws (Kirchhoff, Faraday, Bode)
# - Electromagnetic Theory
#  - EM elements (models with idealized E-H characteristics)
#  - EM laws (Coulomb, Gauss, Maxwell)
# - Newtonian Mechanics
#  - Lumped elements (mass, spring, friction)
#  - Mech. laws (Newton, Hooks)

# %% [markdown]
# ## Theories of Uncertainty
# - Probability theory
#   - What are the elements of probability theory?
#     - Random experiment (an idealized chance mechanism)
#     - The goal is to *predict* results of a random experiment
# - Statistical theory
#   - What are the elements of statistical theory?
#     - Dataset (a set of observations)
#     - The goal is to *propose* a model (random experiment) that could have given rise to the dataset
#
# ## Random Experiment
# As a conceptual model of a simple chance mechanism, a random experiment consists of
# 1. Purpose
#  - What is the context? (configuration, environment, setup)
#     - resistance of this resistor (in my hand) vs.
#     - resistance of a resister of this batch
#  - What are you looking for? (list of possible outcomes to watch)
#     - resistance only (dc analysis)
#     - resistance and reactance (high frequencies)
# 1. Procedure
#  - an unambiguous sequence of actions (clearly specified)
#  - not open for individual interpretation (deterministic)
# 1. Execution
#  - Someone (or robot) carries out the prescribed procedure in the prescribed setup
#  - this is where you may face some uncontrollable and unpredictable influences
#     - in the absence of this you have a deterministic experiment
#       - how many departments in NUCES?
#       - how many departments in an unspecified university
#   - a single execution (also called a trial) is implied in the definition
#      - if multiple trials are needed, change the (specified) procedure (and hence the definition)
# 1. Noting
#  - The possible outcomes of interest are noted (assumed deterministic)
#  - What is noted here is an *actual outcome*
#  - Any constraints (natural or deliberate) in the specified setup will limit what can be noted
#  - outcomes (specified in the statement of purpose) may be too detailed for some problems
#     - results of interest (called events) hide the finer details for convenience
#
# An example is needed to illustrate the definition above.
# ## Die-Throwing Experiment
# 1. Purpose
#  - explain the setup
#  - list the possible outcomes of your interest
#  - what if this is missing?
# 1. Procedure
#  - explain the sequence of actions
#  - give a bad example
#  - what if this is missing?
# 1. Execution
#  - give bad examples
#  - what if this is missing?
# 1. Noting
#  - give a bad example
#  - outcomes/events
#  - what if this is missing?

# %% [markdown]
# ## From Concepts to Math
# <img src="images/concepts_to_math_pe.png" width="70%" />

# %% [markdown]
# ### Examples (Make appropriate assumptions in each case)
# 1. Toss a coin and note the outcome. What are the possible outcomes?
# >$S = \left\{\text{T},\text{H}\right\}$
# 1. Toss a coin twice and note the outcome.
#   - What are the possible outcomes?
#   >$S = \left\{\text{TT},\text{TH},\text{HT},\text{HH}\right\}$
#   - What could be events of your interest?
#     - Say, you are interested in the number of heads, then typical events are
#     >"no head" $\leftrightarrow A_0 = \left\{\text{TT}\right\}$<br>
#     "one head" $\leftrightarrow A_1 = \left\{\text{TH},\text{HT}\right\}$<br>
#     "two heads" $\leftrightarrow A_2 = \left\{\text{HH}\right\}$
# 1. Toss a coin three times and note the outcome.
#   - What are the possible outcomes?
#   >$S = \left\{\text{TTT},\text{TTH},\text{THT},\text{THH},\text{HTT},\text{HTH},\text{HHT},\text{HHH}\right\}$
#   - What could be events of your interest?
#   - Say, you are interested in the number of tails, then typical events are
#     >"no tail" $\leftrightarrow B_0 = \left\{\text{HHH}\right\}$<br>
#     "one tail" $\leftrightarrow B_1 = \left\{\text{THH},\text{HTH},\text{HHT}\right\}$<br>
#     "two tails" $\leftrightarrow B_2 = \left\{\text{TTH},\text{THT},\text{HTT}\right\}$<br>
#     "three tails" $\leftrightarrow B_3 = \left\{\text{TTT}\right\}$
# 1. Toss a coin until the first head occurs.
#   - What are the possible outcomes?
#   >$S = \left\{\text{H},\text{TH},\text{TTH},\text{TTTH},\cdots\right\}$
#   - What could be events of your interest?
#   - Say, you are interested in the number of trials needed for the first head, then typical events are
#     >"no trial" $\leftrightarrow C_0 = \emptyset$<br>
#     "one trial" $\leftrightarrow C_1 = \left\{\text{H}\right\}$<br>
#     "two trials" $\leftrightarrow C_2 = \left\{\text{TH}\right\}$<br>
#     "three trials" $\leftrightarrow C_3 = \left\{\text{TTH}\right\}$
# 1. Toss a coin until the first head occurs and count the number of tosses.
# >$S = \mathbb{N} = \left\{1,2,3,\cdots\right\}$ as the statement contains "count"
# 1. A hacker is repeatedly and persistently trying to break into a company’s computer server. Count the number of attempts needed for a successful break-in.
# >$S = \mathbb{N}$
# 1. Count the number of clicks on a Facebook post in an hour.
# >$S = \left\{0\right\}\cup\mathbb{N}$<br>
# This is a simpler set than the one with the largest element that cannot be determined.
# 1. Measure the lifetime of a light bulb in a typical home environment.
# >$S = \left\{x\in\mathbb{R}:x\ge 0\right\}$<br>
# This is a simpler set than the one with the largest element that cannot be determined.

# %% [markdown]
# ## The Meaning of "Random"
#  - The uncontrollable and unpredictable influences make it impossible to predict the outcome of a single trial
#     - A *random mechanism* is assumed to underlie the influences
#  - The experiment can be repeated under identical conditions
#     - The random mechanism does not change from trial to trial
#     - this is an assumption and cannot be guarranteed to hold  in practice
#       - give a few obvious examples
#     - discernible regularities exist in the frequency of occurrence associated with different outcomes
#       - this needs to be made precise mathematically, but you are not ready for that

# %% [markdown]
# ## Properties of Relative Frequency of an Event
# A random experiment is repeated $n$ times. The occurrence pattern of an event $A$ can be described with the help of quantities defined in the following.
#  - Absolute frequency $a_n(A)$ is the number of occurrences of $A$ in the $n$ trials.
#  - Properties of absolute frequency
#    1. >$0 \le a_n(A) \le n$
#    1. >$a_n(S) = n$
#    1. >$a_n(\emptyset) = 0$
#    1. For disjoint events $A$ and $B$,
#      >$a_n(A\cup B) = a_n(A) + a_n(B)$
#    1. For pairwise disjoint events $A_1, A_2, \ldots, A_m$
#      >$\displaystyle a_{n}\left(\bigcup_{i=1}^{m}A_{i}\right)=\sum_{i=1}^{m}a_{n}\left(A_{i}\right)$
#
#  - Relative frequency
#  >$r_n(A) = \dfrac{a_n(A)}{n}$
#  - Properties of relative frequency
#    1. >$0 \le r_n(A) \le 1$
#    1. >$r_n(S) = 1$
#    1. >$r_n(\emptyset) = 0$
#    1. For disjoint events $A$ and $B$,
#      >$r_n(A\cup B) = r_n(A) + r_n(B)$
#    1. For pairwise disjoint events $A_1, A_2, \ldots, A_m$
#      >$\displaystyle r_{n}\left(\bigcup_{i=1}^{m}A_{i}\right)=\sum_{i=1}^{m}r_{n}\left(A_{i}\right)$
#
#  - Interpretation of relative frequency
#     - The binary occurence of $A$ in trial $i$ can be defined by
#     >$b_{i}\left(A\right)=\begin{cases}
#      1 & A\text{ occurs in trial }i\\
#      0 & A\text{ does not occur in trial }i
#      \end{cases}$
#     - then the absolute frequency can be expressed as the sum
#     >$\displaystyle a_{n}\left(A\right)=\sum_{i=1}^{n}b_{i}\left(A\right)$
#     - and the relative frequency as the arithmetic mean
#     >$\displaystyle r_{n}\left(A\right)=\frac{a_{n}\left(A\right)}{n}=\frac{1}{n}\sum_{i=1}^{n}b_{i}\left(A\right)=\bar{b}_n$
#     - the relative frequency of an event is, in fact, its average occurrence per trial

# %% [markdown]
# ## Statistical Regularity
# <div class="container">
#     <div style="float:left;width:45%">
# 	    <img src="images/stat_regularity_1.png">
#     </div>
#     <div style="float:right;width:54%">
# 	    <img src="images/stat_regularity_2.png">
#     </div>
# </div>

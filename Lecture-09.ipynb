# %% [markdown]
# # EE319 - Probability & Random Processes
# ## *Dr. Ing. Mukhtar Ullah*, FAST NUCES, Fall 2020
# <hr>
#
# ## **Lecture 09** (2020-02-18)

# %% [markdown]
# ### Dependencies among Component Experiments
#
# - In how many ways can a generous person give five differently-colored M&M's to five kids?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - How many four-letter "words" are there with vowels in the middle two places and consonants in the other two, and with no letter repeated?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - How many five-digit numbers ending with 1,2, or 4 are there with no digit repeated?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - In how many ways can $n$ people be seated in a row of $n$ chairs?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - In how many ways can a row of $k$ seats be filled from a set of n people?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
#  - In how many ways can $n$ people be seated in a circle of $n$ chairs?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
#  - In how many ways can 6 different keys be arranged on a keychain?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
#  - In how many ways can a generous person give one M&M each to two children if she has 3 different red, 4 different brown, and different 5 tan ones and the two children insist upon having M&M's o f different colors?
#
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ### Distinguishability Matters
#
# - In how many ways can four objects be put into two boxes?
#   - Distinguishable boxes
#     - distinguishable objects
# <br/>
# <br/>
# <br/>
# <br/>
#     - indistinguishable
# <br/>
# <br/>
# <br/>
# <br/>
#   - Indistinguishable boxes
#     - distinguishable objects
# <br/>
# <br/>
# <br/>
# <br/>
#     - indistinguishable
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ### Additive Counting Rule
#
# - The 54-member Council for Security and Cooperation in Europe wishes to choose 3 member states for different leadership positions. The L lobby decrees that at least one of Lithuania, Lichtenstein, Latvia, and Luxembourg must be chosen. In how many ways can the committee be selected?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# ### Strategic Overcounting
#
# - In how many ways can Faris choose 3 of the 5 colors of M&M's to eat?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# -  In how many ways can $k$ objects be selected as a lot a set of n?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# -  Find the number of different $k$-subsets of a set of cardinality $n$.
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - In how many ways can a three-person subcommittee be chosen from a five-person committee?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - A set of points is chosen on the circumference of a circle so that the number of different triangles with all three vertices among the points is equal to the number of pentagons with all five vertices in the set. How many points are there?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - How many rearrangements of the word LINGUINI are there?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - Derive a formula for the number of rearrangements of a word consisting of $k_1$ copies of letter $1$, $k_2$ copies of letter $2$, and so on up to $k_j$ copies of letter $j$, with $n$ total letters.
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - In how many different ways can a set of cardinality $n$ be partitioned into $j$ subsets of cardinalities $\left\{k_1,k_2,\ldots,k_j\right\}$?

# %% [markdown]
# ### Counting beyond Common Sense
# - A dog trainer wants to buy 8 dogs all of which are either cocker spaniels, Irish setters, or Russian wolfhounds. In how many ways can she make the choice?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - Derive a simple formula for the number of ways to buy $k$ dogs if there are $n$ varieties to choose from.
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - Derive a simple formula for the number of solutions in nonnegative integers of $x_1 +x_2 + \cdots + x_n = k$.
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - In how many ways may five people be seated in a row of twenty chairs given that no two people may sit next to one another?
#
# <br/>
# <br/>
# <br/>
# <br/>
#
# - How many nonnegative integer solutions are there to $x_1 + x_2 + x_3 \le 50$?
#
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ### Principle of Inclusion-Exclusion (PIE)
# - There are 100 students taking language classes at Austin High School. If 60 are taking German and 75 are taking Spanish and these are the only languages taught, how many students take both Spanish and German?
#
# <br/>
# <br/>
# <br/>
# <br/>

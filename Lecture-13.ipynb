# %% [markdown]
# # EE319 - Probability & Random Processes
# ## *Dr.-Ing. Mukhtar Ullah*, FAST NUCES, Spring 2020
# <hr>
#
# ## **Lecture 13** (2020-03-03)
# ## More Applications of Probability (continued)

# %% [markdown]
# ### Quality control
# - A batch of $50$ items contains $10$ defective items. Suppose $10$ items are selected at random and tested. What is the probability that exactly $5$ of the items tested are defective?
# >The base sample space $\mathsf{\Omega}$ has size $50$. The base space can be partitioned into two events: $\mathsf{D}$ for defective items and $\mathsf{D^c}$ for nondefective items. The sequential experiment involves an unordered selection without replacement. ‘Unordered’ because only the number of defective items is of interest. ‘Without replacement’ because it makes no sense to test an item that has already been tested. The sequential experiment has size $\binom{50}{10}$ for the number of ways $10$ items can be selected from $\mathsf{\Omega}$. The event of our interest has size $\binom{10}{5}\binom{40}{5}$ for the number of ways $5$ defective items can be selected from $\mathsf{D}$ and $5$ nondefective items from $\mathsf{D^c}$. The required probability is
# $$\dfrac{\binom{10}{5}\binom{40}{5}}{\binom{50}{10}}$$
#
# ### Die rolls
# - A six-sided die is tossed $12$ times. How many distinct sequences of faces (numbers from $1$ to $6$) have each number appearing exactly twice? What is the probability of obtaining such a sequence?
# >The base sample space $\mathsf{\Omega}$ has size $6$. The $12$-toss sequential experiment has size $6^{12}$ for the number of distinct sequences of faces possible. The appearance of each side twice is in fact its multiplicity in a multinomial cofficient associated with $12$. The number of such distinct sequences is
# $$\binom{12}{2,2,2,2,2,2}$$
# The probability of obtaining such a sequence is
# $$\dfrac{1}{6^{12}}\binom{12}{2,2,2,2,2,2}$$
#
# ### The two-urn experiment
# - A sequential experiment involves repeatedly drawing a ball from one of two urns, noting the number on the ball, and replacing the ball in its urn. Urn $0$ contains a ball with the number $1$ and two balls with the number $0$, and urn $1$ contains five balls with the number $1$ and one ball with the number $0$. The urn from which the first draw is made is selected at random by flipping a fair coin. Urn $0$ is used if the outcome is heads and urn $1$ if the outcome is tails. Thereafter the urn used in a subexperiment corresponds to the number on the ball selected in the previous subexperiment.
# ><img src="images/two_urn_experiment.png" width="60%" />
# >
# >Find the probability of the sequence $0011$?
# $$P_{1\cdot\cdot 4}\left(\{0011\}\right)=P_{1}\left(\{0\}\right)P_{2\mid 1}\left(\{0\}\mid\{0\}\right)P_{3\mid 2}\left(\{1\}\mid\{0\}\right)P_{4\mid 3}\left(\{1\}\mid\{1\}\right)=\frac{1}{2}\times\frac{2}{3}\times\frac{1}{3}\times\frac{5}{6}=\frac{5}{54}$$
#
# ### Repeated Bernoulli trials until the first success
# - A coin is tossed repeatedly until the first heads shows up. Find a probability law for this experiment.
# >The base sample space is $\mathsf{\Omega}=\{\mathrm{H},\mathrm{T}\}$. Assume a base probability distribution
# $$P\left(\{\mathrm{H}\}\right)=p,\quad P\left(\{\mathrm{T}\}\right)=1-p$$
# However, no finite number of tosses can guarrantee the first head. The sequential experiment of ordered selection with replacement has sequences of ever increasing length as outcomes.
# $$\mathsf{\Omega}_{\mathrm{geo}}=\{\mathrm{H},\mathrm{TH},\mathrm{TTH},\ldots\}=\Bigl\{\left(x_{i}\right)_{i\in\left\{ 1,2,\ldots,n\right\} }\mid x_{n}=\mathrm{H},x_{i\ne n}=\mathrm{T},n\in\mathbb{N}\Bigr\}$$
# It can be seen that this does not fit in our classification of four cases of counting as the size $n$ of sequences gets larger and larger without bound, or in mathematical parlance, gets infinitely large. That is not an issue as far as probability calculation is concerned because the product rule of probability is still applicable.<br/>
# >Events of our interest are of the form
# $$\mathsf{A}_{k}=\left\{ \mathrm{T}\right\} ^{k-1}\times\left\{ \mathrm{H}\right\}\leftrightarrow\text{‘}k\text{ tosses are required until the first head occurs’}$$
# Application of the product rule of probability yields what is called a *geometric distribution*.
# $$P_{\mathrm{geo}}\left(\mathsf{A}_{k}\right)=P_{\mathrm{geo}}\left(\left\{ \mathrm{T}\right\} ^{k-1}\times\left\{ \mathrm{H}\right\} \right)=\left[P\left(\left\{ \mathrm{T}\right\} \right)\right]^{k-1}P\left(\left\{ \mathrm{H}\right\} \right)=\left(1-p\right)^{k-1}p$$
#
# ### Repeated Bernoulli trials until the $r$th success
# - A coin is tossed repeatedly until the $r$th head shows up. Find a probability law for this experiment.
# >The base sample space and the base probability distribution are the same as above. As before, the sequential experiment has as outcomes sequences of ever increasing length.
# $$\mathsf{\Omega}_{\mathrm{nb}}=\Bigl\{\left(x_{i}\right)_{i\in\left\{ 1,2,\ldots,n\right\} }\mid x_{i}\in\left\{ \mathrm{H},\mathrm{T}\right\} ,x_{n}=\mathrm{H},\left|\left\{ i\mid x_{i}=\mathrm{H}\right\} \right|=r,n\in\mathbb{N}\Bigr\}$$
# >Define events of the form
# $$\mathsf{A}_{j/ n}\leftrightarrow\text{‘}j\text{ heads occur in }n\text{ tosses’}$$
# that arise in binomial distribution.<br/>
# >Events of our interest take the form
# $$\mathsf{A}_{k\backslash r}=\mathsf{A}_{(r-1)/(k-1)}\times\left\{ \mathrm{H}\right\}\leftrightarrow\text{‘}k\text{ tosses are required until the }r\text{th head occurs’}$$
# Application of the product rule of probability yields what is called a *negative-binomial distribution*.
# $$P_{\mathrm{nb}}\left(\mathsf{A}_{k\backslash r}\right)=P_{\mathrm{bin}}\left(\mathsf{A}_{(r-1)/(k-1)}\right)P\left(\left\{ \mathrm{H}\right\} \right)=\binom{k-1}{r-1}p^{r}\left(1-p\right)^{k-r}$$

# %% [markdown]
# ### Axiomatic Probability Revisited
# #### Why axiomatic approach is more practical
# Recall the two key concepts of Calculus. Both the derivative and integral are, in fact, limits of some sequence. Derivative at a point is the limit of a sequence of slopes of secant lines. The Riemann integral is the limit of a sequence of Riemann sums. An event in probability theory can turn out to be the limit of a sequence of events.
#
# <div class="container">
#     <div style="float:left;width:65%">
# 	    <img src="images/tangent_via_secants.svg">
#     </div>
#     <div style="float:right;width:35%">
# 	    <img src="images/riemann_sum.png">
#     </div>
# </div>

# %% [markdown]
# #### Probability measures are continuous from below.
#
# Suppose you are given a increasing sequence $\mathsf{A}_{1}\subseteq\mathsf{A}_{2}\subseteq\cdots$
# of events with limit $\mathsf{A}=\bigcup_{n=1}^{\infty}\mathsf{A}_{n}$.
# How is the probability $P\left(\mathsf{A}\right)$ of the limit event related to the probabilities $P\left(\mathsf{A}_{n}\right)$ of events in the sequence. Since $\mathsf{A}_{n}=\bigcup_{i=1}^{n}\mathsf{A}_{i}$,
# your intuition should lead you to guess that $P\left(\mathsf{A}\right)$ is the limit of the sequence $P\left(\mathsf{A}_{1}\right)\le P\left(\mathsf{A}_{2}\right)\le\cdots$.
# That, indeed, is the case.
#
# The union $\bigcup_{n=1}^{\infty}\mathsf{A}_{n}$ in the limit can
# be expressed as a disjoint union $\bigcup_{n=1}^{\infty}\mathsf{A}_{n}\setminus\mathsf{A}_{n-1}$
# if we set $\mathsf{A}_{0}=\emptyset$. It follows that
# \begin{align*}
# P\left(\mathsf{A}\right) & =P\left(\bigcup_{n=1}^{\infty}\mathsf{A}_{n}\right)=P\left(\bigcup_{n=1}^{\infty}\mathsf{A}_{n}\setminus\mathsf{A}_{n-1}\right)=\sum_{n=1}^{\infty}P\left(\mathsf{A}_{n}\setminus\mathsf{A}_{n-1}\right)\\
#  & =\lim_{n\rightarrow\infty}\sum_{k=1}^{n}P\left(\mathsf{A}_{k}\setminus\mathsf{A}_{k-1}\right)=\lim_{n\rightarrow\infty}\sum_{k=1}^{n}\left[P\left(\mathsf{A}_{k}\right)-P\left(\mathsf{A}_{k-1}\right)\right]\\
#  & =\lim_{n\rightarrow\infty}\left[P\left(\mathsf{A}_{n}\right)-P\left(\mathsf{A}_{0}\right)\right]=\lim_{n\rightarrow\infty}P\left(\mathsf{A}_{n}\right)
# \end{align*}
# Continuity from below is expressed more succintly by
# $$P\left(\mathsf{A}_{n}\right)\rightarrow P\left(\mathsf{A}\right)\ \text{as}\ \mathsf{A}_{n}\uparrow\mathsf{A}$$
#
# #### Probability measures are continuous from above.
# Suppose you are given a decreasing sequence $\mathsf{A}_{1}\supseteq\mathsf{A}_{2}\supseteq\cdots$
# of events with limit $\mathsf{A}=\bigcap_{n=1}^{\infty}\mathsf{A}_{n}$. The increasing sequence $\mathsf{A}_{1}^{\mathsf{c}}\subseteq\mathsf{A}_{2}^{\mathsf{c}}\subseteq\cdots$ approaches the limit $\mathsf{A^{c}}=\bigcup_{n=1}^{\infty}\mathsf{A}_{n}^{\mathsf{c}}$ which, owing to continuity from below, has probability
# $$P\left(\mathsf{A^{c}}\right)=\lim_{n\rightarrow\infty}P\left(\mathsf{A}_{n}^{\mathsf{c}}\right)=\lim_{n\rightarrow\infty}\left[1-P\left(\mathsf{A}_{n}\right)\right]=1-\lim_{n\rightarrow\infty}P\left(\mathsf{A}_{n}\right)$$
# Probability of the original limit (of the decreasing sequence) then follows
# $$P\left(\mathsf{A}\right)=1-P\left(\mathsf{A^{c}}\right)=\lim_{n\rightarrow\infty}P\left(\mathsf{A}_{n}\right)$$
# Continuity from above is expressed more succintly by
# $$P\left(\mathsf{A}_{n}\right)\rightarrow P\left(\mathsf{A}\right)\ \text{as}\ \mathsf{A}_{n}\downarrow\mathsf{A}$$
#
# Having established continuity from below as well as from above, it is safe to conclude that each probability measure satisfies continuity, that is, for any monotic sequence $\left(\mathsf{A}_{n}\right)_{n\in\mathbb{N}}$, we have
# $$P\left(\lim_{n\rightarrow\infty}\mathsf{A}_{n}\right)=\lim_{n\rightarrow\infty}P\left(\mathsf{A}_{n}\right)$$
# This has been celebrated as the most signifact triumph of the axiomatic approach developed by Kolmogorov as it allows to develop probability theory just like calculus.
#
# #### Setting the stage for a calculus of probabilty
# Remember that calculus was made possible only after the real line was developed as a set with no holes. Equipped with the continuity of probability measures, all we need is a clever way of representing all the events in a problem as (sub)sets of the real line. Since we are more comfortable working with numbers than with sets, we shall
# look for special subsets each determined entirely by a single real number.
#
# ### Uncountable Sets Revisited
# #### *How to generate an event space for the real line?*
#
# Recall the implications of the fact that the set $\mathbb{R}$ of real numbers is uncountable: we cannot assign probabilities in a consistent way to all sets included in the power set $\mathscr{P}\left(\mathbb{R}\right)$. The good news, however, is that all subsets of $\mathbb{R}$ we encounter in practice are included in a smaller $\sigma$-field called a Borel field over the real line, denoted $\mathfrak{B}\left(\mathbb{R}\right)$, and which can be generated by events of the form $\mathsf{B}_{x}=\left(-\infty,x\right]$. Mathematically we write
# $$\mathfrak{B}\left(\mathbb{R}\right)=\sigma\left(\left\{ \mathsf{B}_{x}:x\in\mathbb{R}\right\} \right) \subset \mathscr{P}\left(\mathbb{R}\right)=\sigma\left(\left\{ \{x\}:x\in\mathbb{R}\right\} \right)$$
# Subsets included in Borel field are called Borel sets. Therefore, only Borel sets can be assigned probability in a consistent way (so as to satisfy the Kolmogorov axioms).
#
# We need a convenient notation for the limit of a monotonic sequence of events.
# \begin{align*}
# \mathsf{B}_{a^{-}} & =\lim_{x\uparrow a}\mathsf{B}_{x}=\bigcup_{n=1}^{\infty}\mathsf{B}_{a-1/n}\subset\mathsf{B}_{a}\\
# \mathsf{B}_{a^{+}} & =\lim_{x\downarrow a}\mathsf{B}_{x}=\bigcap_{n=1}^{\infty}\mathsf{B}_{a+1/n}=\mathsf{B}_{a}
# \end{align*}
# Following are a few examples of events thus generated.
# \begin{align*}
# \left(a,\infty\right) & =\left(-\infty,a\right]^{\mathsf{c}}=\mathsf{B}_{a}^{\mathsf{c}}\\
# \left(a,b\right] & =\left(-\infty,b\right]\cap\left(a,\infty\right)=\mathsf{B}_{b}\cap\mathsf{B}_{a}^{\mathsf{c}}\\
# \left(-\infty,b\right) & =\bigcup_{n=1}^{\infty}\left(-\infty,b-1/n\right]=\bigcup_{n=1}^{\infty}\mathsf{B}_{b-1/n}=\mathsf{B}_{b^{-}}\\
# \left[a,\infty\right) & =\left(-\infty,a\right)^{\mathsf{c}}=\mathsf{B}_{a^{-}}^{\mathsf{c}}\\
# \left(a,b\right) & =\left(-\infty,b\right)\cap\left(a,\infty\right)=\mathsf{B}_{b^{-}}\cap\mathsf{B}_{a}^{\mathsf{c}}\\
# \left[a,b\right) & =\left(-\infty,b\right)\cap\left[a,\infty\right)=\mathsf{B}_{b^{-}}\cap\mathsf{B}_{a^{-}}^{\mathsf{c}}\\
# \left[a,b\right] & =\left(-\infty,b\right]\cap\left[a,\infty\right)=\mathsf{B}_{b}\cap\mathsf{B}_{a^{-}}^{\mathsf{c}}\\
# \left\{ a\right\}  & =\left(-\infty,a\right]\cap\left[a,\infty\right)=\mathsf{B}_{a}\cap\mathsf{B}_{a^{-}}^{\mathsf{c}}
# \end{align*}
